# %% [markdown]
# # Problem 1, 30 points: (On the Jaccard distance)

# %% [markdown]
# ## Question 1
# Given the definition of the events \(A\), \(B\), and \(C\):
#
# $$\begin{align*}
# A &= \{ h(x) \neq h(y) \} \\
# B &= \{ h(y) \neq h(z) \} \\
# C &= \{ h(x) \neq h(z) \}
# \end{align*}$$
#
# $$\begin{align*}
# p_1 &= \mathbb{P}(\overline{A} \cap \overline{B} \cap C) \\
#   &= \mathbb{P}(\text{h(x) = h(y), h(y) = h(z), but } h(x) \neq h(z)) \\
#   &= 0 \\
# p_2 &= \mathbb{P}(\overline{A} \cap B \cap \overline{C}) \\
#   &= \mathbb{P}(\text{h(x) = h(y), h(x) = h(z), but } h(y) \neq h(z)) \\
#   &= 0 \\
# p_4 &= \mathbb{P}(A \cap \overline{B} \cap \overline{C}) \\
#   &= \mathbb{P}(\text{h(y) = h(z), h(x) = h(z), but } h(x) \neq h(y)) \\
#   &= 0 \\
# \end{align*}$$
#
# Thus, based on the definitions of the events and their probabilistic interpretations, we can conclude that $ p_1 = p_2 = p_4 = 0 $.
# ## Question 2
# we know that from $p_0$ to $p_7$, only $p_1$, $p_2$, and $p_4$ are invalid.
#
# So we have:
# \begin{align*}
# \mathbb{P}(A) = p_5 + p_6 + p_7 \\
# \mathbb{P}(B) = p_3 + p_6 + p_7 \\
# \mathbb{P}(C) = p_3 + p_5 + p_7\\
# \end{align*}
#
# ## Question 3
#
# To meet the necessary condition, we have:
# $$\mathbb{P}(A) + \mathbb{P}(B) = p_3 + p_5 + 2p_6 + 2p_7$$
# we know for sure that $p_6$ and $p_7$ are strictly positive, so the formular of $\mathbb{P}(A) + \mathbb{P}(B) \geq \mathbb{P}(C)$ is satisfied.
#
# The satisfaction of the triangle inequality shows that the function d(x,y) defined as 1−sim(x,y) obeys the necessary properties and supports the idea that the Jaccard similarity possesses a locality-sensitive hashing scheme.

# %% [markdown]
# # Problem 2

# %% [markdown]
# ## Question 1
#
# **Linearity of Expectation:**
#
# First, let's compute the expected number of false positives for a given hash function $(g_i)$.
#
# \begin{align*}
# E[|T \cap W_i|] = \sum_{z_i \in A} P(z_i \text{ is a false positive under } g_i)
# \end{align*}
#
# where
# \begin{align*}
# P(z_i \text{ is a false positive under } g_i) = P(g(z) = g(z_i) \text{ and } d(z, z_i) > c\lambda).
# \end{align*}
#
# These events are not independent due to the properties of LSH functions. In LSH, the probability of collision is higher for closer points.
# Thus, the probability that two distant points collide (false positive) is typically much lower than the probability that two close points collide.
#
# **Use of Markov's Inequality:**
#
# To show that the sum over all hash functions is less than $3L$ with probability at least $\frac{2}{3}$, we can use Markov's inequality:
#
# \begin{align}
# P(X \geq a) &\leq \frac{E[X]}{a}, \\
# X &= \sum_{i=1}^{L} |T \cap W_i| \text{ and } a = 3L.
# \end{align}
#
# Assuming we find that:
# \begin{align}
# E[X] &= kL \text{ where } k < 3, \\
# P\left(\sum_{i=1}^{L} |T \cap W_i| \geq 3L\right) &\leq \frac{kL}{3L} = \frac{k}{3}.
# \end{align}
#
# For the probability to be less than $\frac{1}{3}$, k must be less than 1.
#
# Given that:
# \begin{align}
# P(g(x) = g(z)) = \frac{1}{n} \text{ for any } x \text{ such that } d(x, z) > c\lambda
# \end{align}
#
# We could easily deduce that k is less than 1 when \( n \) is bigger than 1.
#
#
#
# ## Question 2
#
# $$\begin{align*}\\
# P(g(x) &= g(z)) = \frac{1}{n^\rho} \text{ for any } x \text{ such that } d(x, z) \leq \lambda \text{ for some } \rho < 1, \\
# \text{the probability that } g_j(x^*) &= g_j(z) \text{ for any particular } j \text{ is at least } \frac{1}{n^\rho}, \\
# \text{the probability that } g_j(x^*) &\neq g_j(z) \text{ for any particular } j \text{ is at most } 1 - \frac{1}{n^\rho}, \\
# \text{the probability that } g_j(x^*) &\neq g_j(z) \text{ for all } j \text{ is at most } (1 - \frac{1}{n^\rho})^L.
# \end{align*}$$
#
# Using $ L = n^\rho $:
# \begin{align*}
# P[ g_j(x^*) \neq g_j(z) \, \forall \, 1 \leq j \leq L] \leq (1 - \frac{1}{L})^L < \frac{1}{e}.
# \end{align*}
#
# Using the limit-based definition of the exponential function, specifically
# \begin{align*}
# e^x = \lim_{m \to \infty} (1 + \frac{x}{m})^m.
# \end{align*}
#
# When \( m \) is a finite value greater than or equal to 1, this expression serves as a lower boundary for the series' convergence.
#
#
# ## Question 3
#
# Given a set $A$ and a distance function $d$, the algorithm aims to identify an element $x^*$ such that its distance to some other point $z$ is at most $\lambda$.
#
# Two main ways the algorithm can fail:
#
# 1. **False Negatives**: $x^*$ is hashed to an incorrect bucket. The probability of this event happening is bounded at $e^{-1}$.
#
# $$ P_{\text{false negative}} \leq e^{-1} $$
#
# 2. **False Positives**: $x^*$ is hashed to the correct bucket but is overshadowed by too many other points, specifically more than $3L$.
#
# The combined probability of failure, taking into account both scenarios, is:
#
# $$ P_{\text{fail}} \leq e^{-1} + \left(1 - e^{-1}\right) \times \frac{1}{3} $$
#
# Given that $ P_{\text{fail}} \approx 0.58 $, there's a decent chance that the algorithm might not always return the correct point. But when it succeeds, it ensures that the returned point satisfies the $(c, \lambda)$-ANN condition.
#
# This hashing-based approach, while probabilistic, offers a mechanism to quickly retrieve approximate nearest neighbors under certain constraints.

# %% [markdown]
# # Problem 3, 40 points: (A similarity-matching function)

# %%
#1. Split text into elements: write a function shingles to convert the input
#text into elements of three characters
def shingles(line):
  n=3 #shingles into elements of 3 characters
  res = set()
  for i in range(len(line) - n +1):
    res.add(line[i:i+3].lower())
  return res

# %%
from traitlets import Union
#2. Calculate Jaccard distance: create a function that accepts as imputs two
#sets and compute its Jaccard distance

def jdist(setA, setB):
  inter = len(setA.intersection(setB))
  union = len(setA.union(setB))
  if union == 0:
    return 0
  else:
    sim = inter/union
    return sim

# %%
#3. Test out the results by running the following code:
print(shingles("This function works perfectly"))
# Out:
# {'rks', 'wor', 'n w', ' pe', 's p', 'rfe', ' fu', 'on ', 'cti', 'ion', ' wo', 'ork', 'erf', 'is ', 'thi', 'ctl', 'fun', 'fec', 'tio', 'ks ', 's f', 'nct', 'unc', 'tly', 'ect', 'his', 'per'}

# %%
#4. Use 1 and 3 to write the minhash function. Put the main code inside a try
# except call.

#I have included the lower() in shingles, so I did not put it in this part
def minhash(input_question, compare_question):
    try:
        input_shingles = shingles(input_question)
        compare_shingles = shingles(compare_question)
        return jdist(input_shingles, compare_shingles)
    except Exception as e:
        print(f"An error occurred: {e}")
        return 0

print(minhash("I have a cat", "I have an apple"))
print(minhash("I have a cat", "I have a dog"))
print(minhash("I have a cat", "I have a caf"))
print(minhash("I have a cat", "I have a cat"))

#Observation: We noticed that the similarity increases as the two texts converge
#from each other.
#This is because the number of shared shingles (3-character sequences) between
#the texts increases, thus increasing the Jaccard similarity value.
# Out:
# 0.35294117647058826
# 0.5384615384615384
# 0.8181818181818182
# 1.0

# %% [markdown]
# # Problem 4, 70 points: (Searching via MinHash and Locality Sensitive Hashing)

# %%
! pip install datasketch
! pip install nltk
# Out:
# Collecting datasketch
#   Downloading datasketch-1.6.4-py3-none-any.whl (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.11 in /usr/local/lib/python3.10/dist-packages (from datasketch) (1.23.5)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from datasketch) (1.11.3)
# Installing collected packages: datasketch
# Successfully installed datasketch-1.6.4
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.1)

# %%
 # 1. You may need the folowing packges:
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read csv)
from collections import defaultdict
from tqdm import tqdm # make your loops show a smart progress meter
import nltk # Natural Language Toolkit
import datasketch # Probabilistic data structures for processing and searching very large datasets

# %%
# 2. Extract the data from “train.csv” to the DataFrame qa pairs and take a look on it.
qa_pairs = pd.read_csv("train.csv")
print(qa_pairs.head())
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  What is the step by step guide to invest in sh...
# 1   1     3     4  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2   2     5     6  How can I increase the speed of my internet co...
# 3   3     7     8  Why am I mentally very lonely? How can I solve...
# 4   4     9    10  Which one dissolve in water quikly sugar, salt...
#
#                                            question2  is_duplicate
# 0  What is the step by step guide to invest in sh...             0
# 1  What would happen if the Indian government sto...             0
# 2  How can Internet speed be increased by hacking...             0
# 3  Find the remainder when [math]23^{24}[/math] i...             0
# 4            Which fish would survive in salt water?             0

# %%
#3. Create a random sample of questions from qa pairs. For example you can use
#the following code:
sents_pairs = pd.concat([qa_pairs[qa_pairs['is_duplicate'] == 0].sample(100, random_state=42), qa_pairs[qa_pairs['is_duplicate'] == 1].sample(100, random_state=42)]).reset_index(drop=True)
sents_pairs = sents_pairs.sample(frac=1.)
sents = pd.concat([sents_pairs['question1'], sents_pairs['question2']])

# %%
#4. Represent the questions as single word tokens if they are not stop words:
#• Download ‘stopwords’ from nltk package
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
print(stop_words)

#• Create ‘set_dict’ dictionary which maps question id (eg ‘m23’) to set
#representation of question.
#• Loop through each question, convert them into shingles, and, if the shingle
#isn’t a stopword, add it to a hashset which will be the value for the set dict
#dictionary.
#• Do not froget to lowcase!
#• Additionally create ‘norm dict’ dictionnary which maps question id (eg ‘m23’)
# to actual question (we may use it to evaluate the result).

set_dict = defaultdict(set)
norm_dict = {}

# we define a new shingles function here to remove the words in the stopwords:
def shingles2(line):
    res = set()
    for i in range(len(line) - 3 + 1):
        shingle = line[i:i+3].lower()
        if not any(word in stop_words for word in shingle.split()):
            res.add(shingle)
    return res

for index, row in sents_pairs.iterrows():
    question1 = row['question1'] if pd.notna(row['question1']) else ""
    question2 = row['question2'] if pd.notna(row['question2']) else ""

    q1_shingles = set(shingles2(question1))
    q2_shingles = set(shingles2(question2))
    mid1 = "m" + str(row['qid1'])
    mid2 = "m" + str(row['qid2'])
    set_dict[mid1] = {'question':q1_shingles}
    set_dict[mid2] = {'question':q2_shingles}
    norm_dict[mid1] = {'question':question1}
    norm_dict[mid2] = {'question':question2}
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# {'yourself', 'ain', 'it', 'i', 'about', 'y', "isn't", "needn't", 'so', "don't", 'of', 'these', 'yourselves', 'needn', "shouldn't", 'above', 'ours', 'up', 'not', "hasn't", 'hers', 'for', 'll', 'they', 'on', 'how', "didn't", 'that', 'under', 'and', "you'll", "mightn't", 'herself', 'whom', 'hasn', 't', 'through', 'having', 'than', "couldn't", "haven't", 'your', "aren't", 'o', 'myself', 'mustn', 'weren', 'itself', 'hadn', 'in', 'wouldn', 'same', 'do', "won't", 'wasn', 'won', 'during', 'being', 'once', 'or', 'at', 'its', 'we', 'over', 'such', 'which', 'this', 'our', 'both', 'the', 's', 'any', 'no', 'isn', 'mightn', 'their', 'shan', 'then', 'who', 'own', 'was', 'does', 'now', 'some', "shan't", 'shouldn', 'a', 've', 'had', 'against', 'am', 'to', 'when', 'her', "it's", 'between', 'doing', 'very', 'until', 'have', 'were', 'aren', 'there', 'themselves', 'him', 'himself', "wouldn't", 'while', 'theirs', 'ourselves', 'haven', "should've", "hadn't", 'just', 'nor', "you've", 'couldn', 'where', 'into', 'what', 'too', 'his', 'why', 'but', 'more', 'most', 'are', 'all', 'yours', 'from', 'further', 'by', 'few', 'did', 'you', 'be', 'as', 'those', 'if', 'other', "you'd", 'an', 'because', 'he', "wasn't", "that'll", "mustn't", 'out', 'again', 'been', 'after', 'below', 'my', 'will', 'before', 'is', 'should', 'only', 'don', 'can', 'didn', 'ma', "doesn't", 'has', 'she', 'them', 'down', 're', "she's", "you're", 'off', 'here', 'each', 'doesn', "weren't", 'd', 'with', 'm', 'me'}

# %%
#5. Create minHash signatures:
#• Fix the number of permutations for the MinHash algorithm ‘num perm’.
from datasketch import MinHash, MinHashLSH
num_perm = 128
min_dict = defaultdict()

#• Create ‘min dict’ which maps question id (eg ‘m23’) to min hash signatures.
# You can use ‘MinHash’ from ‘datasketch’ package

#• Loop through all the set representations of questions and calculate the
# signatures and store them in the ‘min dict’ dictionary
for qid, question in set_dict.items():
    m = MinHash(num_perm=num_perm)
    for word in question:
        m.update(word.encode('utf8'))
    min_dict[qid] = m

# %%
#6. LSH can be used with MinHash to achieve sub-linear query cost. Create LSH
#index using
#‘MinHashLSH’ from ‘datasketch’ package
#• Set the Jaccard similarity threshold (e.g. =0.4) as a parameter in MinHashLSH.
#• Loop through the signatures or keys in the ‘min dict’ dictionary and store
#them. Datasketch stores these in a dictionary format, where the key is a
#question and the values are all the questions deemed similar based on the
#threshold.

# Create LSH index
lsh = MinHashLSH(threshold=0.9, num_perm=128)
for qid, question in min_dict.items():
    lsh.insert(qid, question)

# %%
#7. Giving the MinHash of the query set, retrieve the keys (m1, m2 etc.) that references sets with
#approximate Jaccard similarities using the following code:
big_list = []
for query in min_dict.keys():
    big_list.append(lsh.query(min_dict[query]))

# %%
# 8. Check some of the resulting pairs.
print(big_list[1])

for similar_qids in big_list[:1]:
    if len(similar_qids) > 1:
        print("Similar Questions:")
        for qid in similar_qids:
            print(f"{qid}: {norm_dict[qid]}")
        print("\n")
# Out:
# ['m124462', 'm439792', 'm282561', 'm100016', 'm69309', 'm2967', 'm250889', 'm405081', 'm57981', 'm27590', 'm492701', 'm353430', 'm24579', 'm282562', 'm62534', 'm52933', 'm3261', 'm89762', 'm69441', 'm114270', 'm224286', 'm6804', 'm483982', 'm19396', 'm91054', 'm392566', 'm477323', 'm169542', 'm73778', 'm217540', 'm9689', 'm240903', 'm175541', 'm76151', 'm95929', 'm323250', 'm344176', 'm232382', 'm494536', 'm118179', 'm520710', 'm218693', 'm232380', 'm10660', 'm260132', 'm46019', 'm91752', 'm36824', 'm66399', 'm204180', 'm300205', 'm440974', 'm46707', 'm322361', 'm289430', 'm161926', 'm13229', 'm35498', 'm406872', 'm104738', 'm520709', 'm229367', 'm92770', 'm104632', 'm117107', 'm91055', 'm534659', 'm359288', 'm244784', 'm175988', 'm412935', 'm9690', 'm27254', 'm55023', 'm153113', 'm43839', 'm91751', 'm27684', 'm144297', 'm58947', 'm13230', 'm401254', 'm477324', 'm98621', 'm121961', 'm245592', 'm76419', 'm379108', 'm308111', 'm90104', 'm327321', 'm31008', 'm94611', 'm129768', 'm202142', 'm283012', 'm367179', 'm54749', 'm181961', 'm131852', 'm505765', 'm64647', 'm117216', 'm234986', 'm43251', 'm322516', 'm432426', 'm22347', 'm35646', 'm132417', 'm37031', 'm21553', 'm199263', 'm359289', 'm254685', 'm260911', 'm33833', 'm3875', 'm21766', 'm274940', 'm159934', 'm319111', 'm510515', 'm380427', 'm510514', 'm59839', 'm37700', 'm109162', 'm30511', 'm31366', 'm37699', 'm268193', 'm128774', 'm112119', 'm60729', 'm523126', 'm414419', 'm20395', 'm317965', 'm183277', 'm220786', 'm2559', 'm95930', 'm153112', 'm201197', 'm119100', 'm490118', 'm154523', 'm289429', 'm246098', 'm362975', 'm250890', 'm18525', 'm70814', 'm243695', 'm405080', 'm392565', 'm171444', 'm47801', 'm451794', 'm254906', 'm59840', 'm362339', 'm127036', 'm143138', 'm331415', 'm79226', 'm534660', 'm238253', 'm58954', 'm4738', 'm159665', 'm329303', 'm362974', 'm128521', 'm451132', 'm426274', 'm164801', 'm245156', 'm268218', 'm73326', 'm90105', 'm342507', 'm70813', 'm175987', 'm406323', 'm39180', 'm80922', 'm170296', 'm58948', 'm117298', 'm319110', 'm43796', 'm24131', 'm308022', 'm503770', 'm284107', 'm93968', 'm109446', 'm98077', 'm227728', 'm21765', 'm43681', 'm133681', 'm34325', 'm7787', 'm25936', 'm76150', 'm53681', 'm235353', 'm3902', 'm50805', 'm87551', 'm171443', 'm16253', 'm19374', 'm329938', 'm98884', 'm127037', 'm34006', 'm406322', 'm701', 'm69244', 'm323845', 'm9662', 'm301690', 'm440973', 'm91611', 'm159764', 'm367176', 'm494537', 'm148518', 'm445856', 'm235407', 'm119099', 'm383735', 'm30366', 'm30365', 'm384669', 'm128309', 'm193672', 'm284106', 'm329304', 'm476088', 'm18328', 'm156533', 'm308112', 'm237440', 'm521421', 'm427238', 'm503769', 'm510835', 'm5107', 'm463211', 'm492700', 'm61676', 'm117452', 'm30799', 'm23349', 'm534876', 'm109445', 'm124683', 'm232383', 'm341616', 'm165628', 'm42649', 'm35062', 'm486471', 'm63530', 'm159763', 'm94113', 'm187967', 'm414420', 'm498655', 'm299199', 'm76418', 'm428319', 'm412185', 'm110110', 'm181960', 'm198295', 'm294153', 'm36914', 'm240902', 'm131853', 'm103961', 'm23706', 'm63555', 'm23299', 'm445855', 'm385300', 'm281947', 'm23039', 'm27341', 'm131474', 'm17595', 'm329937', 'm154869', 'm121435', 'm45456', 'm406873', 'm379107', 'm246097', 'm69310', 'm131630', 'm342506', 'm463210', 'm104095', 'm94610', 'm429810', 'm9631', 'm198296', 'm174979', 'm281948', 'm94094', 'm13003', 'm2718', 'm27685', 'm375609', 'm51468', 'm375230', 'm229366', 'm147093', 'm42806', 'm427239', 'm63529', 'm204181', 'm401253', 'm27734', 'm274941', 'm223750', 'm38000', 'm76195', 'm79612', 'm322517', 'm432427', 'm344175', 'm128522', 'm296359', 'm20789', 'm72988', 'm2854', 'm497032', 'm103456', 'm101302', 'm476089', 'm242288', 'm174980', 'm241127', 'm161679', 'm114271', 'm191748', 'm25032', 'm443757', 'm505764', 'm33734', 'm197944', 'm56302', 'm161927', 'm223751', 'm413830', 'm145009', 'm86061', 'm451793', 'm140418', 'm439793', 'm8880', 'm480129', 'm131882', 'm30800', 'm19375', 'm426273', 'm31340', 'm362338', 'm15795', 'm104631', 'm31365', 'm30512', ' ...
# Similar Questions:
# m124462: {'question': 'What should I do to grow my hair in a week?'}
# m439792: {'question': "How would I dress in the mid to late 80's gym wear that carried over into the year 1990 if I'm a guy?"}
# m282561: {'question': 'What is the corporate culture like at James River Insurance? How is the culture different than other companies?'}
# m100016: {'question': 'What is the best way to lose weight: cardio or strength workouts?'}
# m69309: {'question': 'How do you get rid of dry or sore throat?'}
# m2967: {'question': 'How can I make a healthy home made pizza?'}
# m250889: {'question': 'What are the responsibilities of a product design manager at Quora?'}
# m405081: {'question': "Why is 'Step daughter' not been included in the defination of Relative under section 2(77) of Companies Act 2013 and rules made there under?"}
# m57981: {'question': 'What penis size do women prefer?'}
# m27590: {'question': 'How do I concentrate in studies?'}
# m492701: {'question': 'Should I take a top-up home loan for doing up my new house interiors, if I have the equivalent cash to fund it?'}
# m353430: {'question': 'Does the sun give vitamin D or does it force the body to produce vitamin D?'}
# m24579: {'question': 'How can I increase traffic to a story blog?'}
# m282562: {'question': 'What is the corporate culture like at Aspen Insurance? How is the culture different than other companies?'}
# m62534: {'question': 'Which is the toughest programming language?'}
# m52933: {'question': 'How close are we to world war?'}
# m3261: {'question': 'How can I increase traffic on my blog?'}
# m89762: {'question': 'How do I order from Flipkart from the USA?'}
# m69441: {'question': 'How can I ask my question on Quora?'}
# m114270: {'question': 'Does Ecuador keep records of people who go missing in national parks and wilderness areas? If not, why not?'}
# m224286: {'question': 'Which is the best company to work with?'}
# m6804: {'question': 'How should I stop masturbating?'}
# m483982: {'question': 'Is Donald Trump a racist?'}
# m19396: {'question': 'Why does 500 and 1000 Rs notes banned by GOI and new notes of 500 and 2000 are issued?'}
# m91054: {'question': 'Will dividing Nigeria into 3 different countries stop corruption?'}
# m392566: {'question': 'Does intuition work out?'}
# m477323: {'question': 'Has the "Obama Out" speech been inspired by the Bilbo Baggins\' birthday speech?'}
# m169542: {'question': 'What is the algorithm used to reserve ticket in Indian Railways?'}
# m73778: {'question': 'Christianity: What is the difference between Roman Catholics and Protestants?'}
# m217540: {'question': 'How do I get more views in YouTube?'}
# m9689: {'question': 'What is awesome?'}
# m240903: {'question': 'What is sanatana dharma?'}
# m175541: {'question': 'What can a Tinder scammer do with my phone number?'}
# m76151: {'question': 'Do Harvard undergraduates really have no time to sleep?'}
# m95929: {'question': "What is Apple's battery replacement policy?"}
# m323250: {'question': 'Will top tech companies (Google/Facebook/Dropbox) make a job offer from a graduate from a non-top university?'}
# m344176: {'question': 'Why do you support the TPP?'}
# m232382: {'question': 'What is the difference between omniscient and omnipotent?'}
# m494536: {'question': "Why don't Indian's fight against reservation?Who else thinks some reservation should be on economic grounds and not caste?"}
# m118179: {'question': 'What if there is a nuclear war between russia and U.S, who would win?'}
# m520710: {'question': 'How many planes do IAF have?'}
# m218693: {'question': "What happened to and why aren't we using the relatively safe Thorium Cycle for nuclear power?"}
# m232380: {'question': 'Do employees at Navigators Group have a good work-life balance? Does this differ across positions and departments?'}
# m10660: {'question': 'When will I stop thinking about what other people think?'}
# m260132: {'question': 'Is Atheism name of just another religion?'}
# m46019: {'question': 'Will you marry a non-virgin girl?'}
# m91752: {'question': 'What are some unknown true facts about Adolf hitler?'}
# m36824: {'question': 'Do employees at Paramount Group have a good work-life balance? Does this differ across positions and departments?'}
# m66399: {'question': 'Under what circumstances would the production possibility curve be bowed in towards the origin?'}
# m204180: {'question': 'Can I get some IMP questions for CAT 2016 so that I cover atleast 90% syllabus in 1 month?'}
# m300205: {'question': 'Why do England, Wales, Scotland and Northern Ireland compete together as the UK at the Olympics but independently for international football tournaments such as the World Cup?'}
# m440974: {'question': 'What feature does erlang have, but scala+akka does not? And vice-versa?'}
# m46707: {'question': 'What are some best horror movies?'}
# m322361: {'question': 'Why does the Quora app need access to my contacts?'}
# m289430: {'question': "What's more important for a man? His GF's outer beauty, or her inner beauty?"}
# m161926: {'question': 'What did cavemen eat?'}
# m13229: {'question': 'Do cops really check the license plate of the car in front of them?'}
# m35498: {'question': 'Do people post questions in Quora just so that they can skip searching in Google for a few minutes?'}
# m406872: {'question': "What are the best restaurants to try when visiting Jacksonville, FL? What should you try while you're there?"}
# m104738: {'question': "Do virtual particles and energy in vacuum really exist? How do we know if they exist if we can't observe them? Where are they?"}
# m520709: {'question': 'How many fighter planes does India have and what is its ranking in the world in terms of the number of fighter planes and the power of IAF?'}
# m229367: {'question': 'Why are people obsessed with psychopaths?'}
# m92770: {'question': 'How do I start learning about artificial intelligence?'}
# m104632: {'question': 'Was Thomas Jefferson a Unitarian?'}
# m117107: {'question': "Why aren't we using thorium designs in nuclear reactors?"}
# m91055: {'question': 'Would Nigeria be better off if it were partitioned into 3 countries (north, southwest, southeast)?'}
# m534659: {'question': 'How can I prepare best to get into an international graduate school for music composition?'}
# m359288: {'question': 'What is the search algorithm used by the Google search engine? What is its complexity?'}
# m244784: {'question': 'I have a cooking pot that is made from 100% copper. Can it be healthy?'}
# m175988: {'question': 'If God agrees to answer any one of your questions with truth, what would you ask?'}
# m412935: {'question': 'Is it really possible to increase penis size and girth naturally?'}
# m9690: {'question': 'What is awesome? Why?'}
# m27254: {'question': 'What are the best Books for Signals And Systems?'}
# m55023: {'question': 'Which celebrities are on Quora?'}
# m153113: {'question': 'What is the tastiest Indian dish?'}
# m43839: {'question': 'How was the KVPY 2016 SA paper? What is the expected cutoff?'}
# m91751: {'question': 'What are some little known facts about Adolf Hitler?'}
# m27684: {'question': 'At CPT level, is the material provided by ICAI sufficient or should I refer some other?'}
# m144297: {'question': 'How can I get 99 percentile and above in CAT 2016?'}
# m58947: {'question': 'How do I write a book? How to start? What knowledge should be gained before writing a book?'}
# m13230: {'question': 'Why do cops not pull over cars without license plates?'}
# m401254: {'question': 'What universities does Tesla Motors recruit new grads from? What majors are they looking for?'}
# m477324: {'question': 'Does Obama ever write his own speeches?'}
# m98621: {'question': 'How do I add an image to a question on Quora?'}
# m121961: {'question': 'How do I manage myself in Mumbai as a working girl in an IT firm, but preferred to live in a seperate accomodation?'}
# m245592: {'question': 'Productivity: What should the 95% of Hollywood aspiring actors who are out-of-work do with their lives with all the downtime in L.A.?'}
# m76419: {'question': 'What is the HBO commercial song?'}
# m379108: {'question': 'Did you read the novel by Ayn Rand "Atlas Shrugged"?'}
# m308111: {'question': 'Can a deceased person win the Nobel Peace Prize?'}
# m90104: {'question': 'What is the scope of civil engineering in India?'}
# m327321: {'question': "Given what's happening in the world today, do you think we may be heading for a world war?"}
# m31008: {'question': 'What are the living conditions in Rockville, Maryland and how does it compare to Gaithersburg?'}
# m94611: {'question': 'Does scaling and polishing make teeth weak?'}
# m129768: {'question': "Have you ever found out your friend doesn't want you to be better than him/her?"}
# m202142: {'question': 'How do I know if someone accept your request in snapchat?'}
# m283012: {'question': "When can I reapply for a USA B1 visa after refusal. I'm a police officer willing to attend the IACP conference?"}
# m367179: {'question': 'How do I become a literary agent?'}
# m54749: {'question': 'Why do people ask questions on Quora that could simply be googled?'}
# m181961: {'question': 'What are extensive properties? What are some examples?'}
# m131852: {'question': 'What types of questions will Akamai ask in the first round for platform engineer?'}
# m505765: {'question': 'Will helicopter parenting in the future going to be the societal norm in America?'}
# m64647: {'question': 'Is it really important to graduate from top universities to get into top tech companies like Facebook, Google, etc?'}
# m117216: {'question': 'What do you do to achieve peace of mind?'}
# m234986: {'question': 'Is smoking weed worth it?'}
# m43251: {'question': 'How can I know if a guy at the gym is interested in me?'}
# m322516: {'question': 'Is my US income taxable if I am working on OPT status?'}
# m432426: {'question': 'How do we talk about bad words to young kids?'}
# m22347: {'question': 'What are the strongest majors in terms of job prospects and what are the weakest majors at Mills College?'}
# m35646: {'question': 'Under what circumstances would the production possible curve bowed in towards the origin?'}
# m132417: {'question': 'How can we reduce masturbating?'}
# m37031: {'question': 'Can god make a rock so heavy that he couldn’t lift it?'}
# m21553: {'question': 'What are some of the top paying career options after doing a B.Tech in mechanical engineering?'}
# m199263: {'question': 'What are literary agents? How do they work?'}
# m359289: {'question': 'What web search algorithm does Google use? How does Google rank the webpages? How does the Google search work?'}
# m254685: {'question': 'What do different ear piercings mean?'}
# m260911: {'question': 'How do you get to know if a guy is really interested in you during gym?'}
# m33833: {'question': 'Is this move of banning 500 & 1000 Rupee notes right?'}
# m3875: {'question': "With a forgotten Gmail password, how do you find an old Gmail password when you don't remember the recovery information?"}
# m21766: {'question': 'What are some exceptional shlokas from Mahabharat?'}
# m274940: {'question': "Why did only the US and the USSR became the superpowers after WW2? Why didn't the UK and France became superpowers as they were far less devastated by the war than the USSR?"}
# m159934: {'question': 'What are your fondest childhood memory?'}
# m319111: {'question': 'I had one set of pictures of my wife and another set for me in my iPhone (OS 10). I merged the two. How do I unmerge and start over?'}
# m510515: {'question': 'Can I receive WhatsApp messages both on PC and mobile?'}
# m380427: {'question': 'Even though people are educated, and even after they have knowledge of science, why do they still believe in God?'}
# m510514: {'question': 'Can I receive WhatsApp messages on my PC?'}
# m59839: {'question': 'How do you remove Sharpie from skin?'}
# m37700: {'question': 'How do you earn cash online in September 2016?'}
# m109162: {'question': 'What is editor?'}
# m30511: {'question': 'How does the Wi-Fi on airplanes work?'}
# m31366: {'question': 'Beach ave elmwood?'}
# m37699: {'question': 'How do you earn small amounts of cash online in September 2016?'}
# m268193: {'question': 'Who are some celebrities that have a Quora account?'}
# m128774: {'question': 'What are some names of big producers of b2b products with zero marginal cost? For example a b2b software producer?'}
# m112119: {'question': 'What are some of your favorite childhood memories?'}
# m60729: {'question': 'What are the career options for an electrical and electronics engineer in the IOT field?'}
# m523126: {'question': 'Is it safe to swim in the ocean at night?'}
# m414419: {'question': 'If I change my WhatsApp no. using the change number function, will all the chats and groups associated with the old no. also be deleted?'}
# m20395: {'question': 'What are the different layers of the atmosphere?'}
# m317965: {'question': 'What can I do on a boring day at work?'}
# m183277: {'question': "What are some mind-blowing Smartphone inventions that exist that most people don't know about?"}
# m220786: {'question': 'Why have oceans been explored less thoroughly than space?'}
# m2559: {'question': 'What are the best ways to lose weight?'}
# m95930: {'question': 'Does AppleCare cover batteries?'}
# m153112: {'question': 'What are the tastiest Indian vegetarian dish?'}
# m201197: {'question': 'What will Hillary prioritize in her first hundred days of office?'}
# m119100: {'question': 'Will I get into Jadavpur University with a rank of 4821 in the WB JEE 2015?'}
# m490118: {'question': 'Are "diminishing marginal product," "increasing marginal costs" and "decreasing returns to scale" the same thing?'}
# m154523: {'question': 'Which Indian food dishes can one cook by making use of a microwave oven?'}
# m289429: {'question': 'How beautiful was Sarai of the bible that in her old age King of Gerar wanted her as his wife?'}
# m246098: {'question': 'What is the best introductory abstract algebra textbook? Why?'}
# m362975: {'question': 'How was Clash of Clans made?'}
# m250890: {'question': 'Do people use Quora during work?'}
# m18525: {'question': 'What are the career options after electrical engineering excluding joining the MNCs?'}
# m70814: {'question': 'Why is "The Grapes of Wrath" a classic?'}
# m243695: {'question': 'Can you ever forget your first love?'}
# m405080: {'question': 'Why is "step-daughter" not included in the definition of relative under the Indian Companies Act, 2013?'}
# m392565: {'question': 'Does intuition really work?'}
# m171444: {'question': 'What do villi do in the digestive system?'}
# m47801: {'question': 'What happened to people who sold off all their belongings in 2012 in preparation for the end of the world?'}
# m451794: {'question': 'MD5 has been broken for a while now. What is a better way to ensure data integrity?'}
# m254906: {'question': 'How shall I prepare to score more than 99 percentile in CAT 2016?'}
# m59840: {'question': 'How do you use Sharpie ink from skin?'}
# m362339: {'question': 'Is there any option to change your youtube username?'}
# m127036: {'question': 'Who will be the next PM of India in Election 2019?'}
# m143138: {'question': 'How should I improve my aptitude?'}
# m331415: {'question': 'Princeton University: Why was the name changed from College of New Jersey?'}
# m79226: {'question': 'Can anyone tell me some real life karma experiences?'}
# m534660: {'question': 'What is it like to learn music composition at USC?'}
# m238253: {'question': 'How do I jailbreak iOS 9.2.1?'}
# m58954: {'question': 'Who will win war between Russia and US?'}
# m4738: {'question': 'Is it possible that global warming is a hoax?'}
# m159665: {'question': 'What are the top torrent sites?'}
# m329303: {'question': 'Is there any need to have an extra talent to impress the other gender?'}
# m362974: {'question': 'What are some good Indian clans in Clash of Clans?'}
# m128521: {'question': 'What factors should I consider while shortlisting a university?'}
# m451132: {'question': 'How do I think out of the box? How do I learn to think out of the box?'}
# m426274: {'question': 'How does it feel to date Ivanka Trump?'}
# m164801: {'question': 'What are the reasons behind nuclear energy being non-renewable?'}
# m245156: {'question': 'Are there cottonmouth snakes in Virginia?'}
# m268218: {'question': 'What are some easy ways of making money online?'}
# m73326: {'question': 'How do I start with learning a new language?'}
# m90105: {'question': 'What is there in civil engineering? Is there a scope of civil engineering in India?'}
# m342507: {'question': 'How is Yuvraj Singh in real life?'}
# m70813: {'question': 'What is "The Grapes of Wrath" about?'}
# m175987: {'question': 'What question would you ask to GOD if He would answer to only one question?'}
# m406323: {'question': 'How to activate windows 10?'}
# m39180: {'question': 'What are the pros and cons of marrying a woman who is older than me?'}
# m80922: {'question': 'How do I jailbreak iOS 9.3.4?'}
# m170296: {'question': 'How can we lose weight without doing any workout?'}
# m58948: {'question': 'How do I start writing my own book?'}
# m117298: {'question': 'Which side of the ear being pierced means being gay? Is there even such a thing as a gay piercing?'}
# m319110: {'question': 'I had one set of pictures of my wife and another set for me. I merged the two. How do I unmerge and start over?'}
# m43796: {'question': 'Can the penis size (length or girth) be permanently increased?'}
# m24131: {'question': 'What is the best way to overcome an porn addiction?'}
# m308022: {'question': 'Should I learn JavaScript?'}
# m503770: {'question': 'What could be the revenue model for a blogging company?'}
# m284107: {'question': 'What are some tips to crack the IIT-JEE?'}
# m93968: {'question': 'How do I recover my permanently deleted emails in Gmail?'}
# m109446: {'question': 'What was the rudest yet honest comment a child has said to you?'}
# m98077: {'question': "What happened to the famous people who believed and confirmed the world would end in 2012 and what do they say why it didn't happen?"}
# m227728: {'question': 'What gives you peace of mind?'}
# m21765: {'question': 'How many parvas are there in the Mahabharat?'}
# m43681: {'question': 'Why does the UK compete as the UK in the Olympics but as individual countries in the World Cup?'}
# m133681: {'question': 'Is climate change the same as global warming?'}
# m34325: {'question': 'What are the best way to improve problem solving skills?'}
# m7787: {'question': 'Harvard College Courses: What is general shopping advice for Latin classes?'}
# m25936: {'question': 'What was the most important decision you made in your life?'}
# m76150: {'question': 'How many hours a day do Harvard students sleep? At what time do Harvard students sleep?'}
# m53681: {'question': 'How do I recover permanently deleted emails in gmail?'}
# m235353: {'question': 'What is it like to be an editor (fiction)?'}
# m3902: {'question': 'How do I concentrate better in my studies?'}
# m50805: {'question': "What's your 2017 new year resolution?"}
# m87551: {'question': 'Are there real life karma police?'}
# m171443: {'question': 'In the digestive system, what is egestion?'}
# m16253: {'question': 'How can one earn money on Quora?'}
# m19374: {'question': 'Will the 2016 MacBook Pro be released in the September release?'}
# m329938: {'question': 'What is the medium used in the Arnolfini Portrait?'}
# m98884: {'question': 'What is the big bone of contention between Catholics and Protestants?'}
# m127037: {'question': 'Who will be the next prime minister in India in 2019?'}
# m34006: {'question': 'Why only holy passport (skin color) is valid?'}
# m406322: {'question': 'Why is my Windows 10 already activated?'}
# m701: {'question': 'Harvard College Courses: What is general shopping advice for Turkish classes?'}
# m69244: {'question': 'Is it healthy to swim in the ocean everyday?'}
# m323845: {'question': 'What should I do to enjoy my life?'}
# m9662: {'question': 'What Is your New year resolutions in 2017?'}
# m301690: {'question': 'What are the best companies to work for?'}
# m440973: {'question': "What's the best fit for a concurrent app: Scala+Akka or Erlang?"}
# m91611: {'question': 'Which are the best movies of Hollywood?'}
# m159764: {'question': 'Should I buy the iPhone 6s or an SE?'}
# m367176: {'question': "Men : Would you feel conned if you found out your girlfriend had plastic surgery even if you weren't planning to have kids with her?"}
# m494537: {'question': "Why don't the Indian people fight against reservation and the quota system?"}
# m148518: {'question': 'Why has Narendra Modi not appointed any Lokpal yet?'}
# m445856: {'question': 'What makes a civil engineer?'}
# m235407: {'question': 'What are the four layers of the atmosphere?'}
# m119099: {'question': 'How do I apply for admission in Jadavpur University through JEE MAINS 2015?'}
# m383735: {'question': 'What are the living conditions in Rockville, Maryland and how does it compare to Laytonsville?'}
# m30366: {'question': 'Will the drop in oil prices discourage further drilling and oil exploration in the USA?'}
# m30365: {'question': "Ignoring modern (and even archaic) exploration techniques, what are the odds of 'striking oil' by drilling at random?"}
# m384669: {'question': "I cut my hair and I don't like it. What should I do to make it grow fast?"}
# m128309: {'question': 'How do I know who is following me on Snapchat?'}
# m193672: {'question': "Why do people still believe in 'God'?"}
# m284106: {'question': 'What are some revision tips for JEE?'}
# m329304: {'question': 'What do you need to develop your talent in Africa?'}
# m476088: {'question': 'Is it safe to use expire d hair oil?'}
# m18328: {'question': 'What are the best horror movies that will keep you up at night?'}
# m156533: {'question': 'Is there any chance that Donald Trump will win this election?'}
# m308112: {'question': 'When will Kim Kardashian win the Nobel Prize for peace?'}
# m237440: {'question': 'How will I get a new high PR social bookmarking sites list in 2014 to follow?'}
# m521421: {'question': 'What are some good books on Signal and Systems?'}
# m427238: {'question': 'Which computer programming language is harder: C++ or Java?'}
# m503769: {'question': 'What is the revenue model for blogging?'}
# m510835: {'question': 'Who are the scammers on FB?'}
# m5107: {'question': 'How do I enjoy the life?'}
# m463211: {'question': "If an NFL team on offense is one inch away from their own goal line (99.9 yards or so away from a touchdown), does that mean they can get as many penalties as they want since they can't be pushed back any further?"}
# m492700: {'question': 'Do I legally have to let my employer know that my spouse owns a potential competitor company?'}
# m61676: {'question': 'How do I reset my password to Gmail without my recovery information?'}
# m117452: {'question': 'How can I get more views on YouTube?'}
# m30799: {'question': 'Which is a good inpatient drug and alcohol rehab center in Madison County IL?'}
# m23349: {'question': 'Why do humans have 5 fingers? Why not 4 or 6?'}
# m534876: {'question': "Can I eat a box of food which is just on the 'used by' date?"}
# m109445: {'question': 'What is the most brutally honest thing a child has ever said to you?'}
# m124683: {'question': 'Can something bad happen if my gf does post orgasm torture to me?'}
# m232383: {'question': 'What are the differences between omniscient and omnipotent?'}
# m341616: {'question': 'Could a bipartisan impeachment of Trump and Pence happen? Could it be likely?'}
# m165628: {'question': 'What is the difference between a SWAT team and Military special forces?'}
# m42649: {'question': 'Which are the best Hollywood movies of all time?'}
# m35062: {'question': 'How can you make money from Quora?'}
# m486471: {'question': 'Which is the best Javascript Framework for beginners?'}
# m63530: {'question': "What do you do when you're bored at home alone (besides Quora) in the middle of the night to connect with people?"}
# m159763: {'question': 'Should I sell an iPhone 6s and buy an iPhone SE?'}
# m94113: {'question': 'Will you marry a girl who is not virgin?'}
# m187967: {'question': 'Which is the best line in a Bollywood movie?'}
# m414420: {'question': "I sent a WhatsApp message and it has 1 tick, it's in the server but not yet delivered. If I change my mobile number, will the message reach them showing my old or my new number?"}
# m498655: {'question': 'How does one forget your first love?'}
# m299199: {'question': 'Why is Arvind Kejriwal opposing scrapping of Rs500 and Rs1000 notes scheme by Modi government?'}
# m76418: {'question': "What's the song in the new Gatorade commercial?"}
# m428319: {'question': 'Are there cottonmouth snakes in Pennsylvania?'}
# m412185: {'question': 'Do girls get turned on when they see an erect penis?'}
# m110110: {'question': 'Who is the most overrated actor in Hollywood?'}
# m181960: {'question': 'What are some examples of extensive properties?'}
# m198295: {'question': 'Can a mortar shell be fired accurately without a barrel to direct its trajectory?'}
# m294153: {'question': 'Is the climate an hoax?'}
# m36914: {'question': 'How can I improve my ability of solving problems?'}
# m240902: {'question': 'How did the Sanatana Dharma come into existence?'}
# m131853: {'question': 'What kind of questions should not be asked on Quora?'}
# m103961: {'question': 'Did someone order an arduino from protocentral?'}
# m23706: {'question': 'Why is Donald Trump not racist?'}
# m63555: {'question': 'What is the fastest method for learning a foreign language?'}
# m23299: {'question': "How google's captcha recaptcha works?"}
# m445855: {'question': 'What is the best way to make money as a civil engineer? Which is the most rewarding stream?'}
# m385300: {'question': "Modi Ji was very positive about the Lokpal before coming to power. Why hasn't he appointed a Lokpal committee yet?"}
# m281947: {'question': 'How can you overcome your envy of people who are your age but are far more successful than you?'}
# m23039: {'question': 'What is the meaning of PQWL, RLWL, GNWL, RLGN, RSWL, CKWL, in a railway waiting list?'}
# m27341: {'question': 'What does Hillary Clinton plan on doing during her first 100 days in office if elected?'}
# m131474: {'question': 'What are ways to lose 20 lbs in four months?'}
# m17595: {'question': 'How do I increase body height?'}
# m329937: {'question': '15yr old boy. height5"7 dad 5"7 mom 5"3 bro5"11.observed some beard on face. and masturbate twice . how tall will I be?'}
# m154869: {'question': 'Why does Quora need my Google contacts?'}
# m121435: {'question': 'Is nuclear energy "renewable energy"?'}
# m45456: {'question': "Can energy be borrowed from vacuum(to be returned immediately)? If this happens how do we know vacuum energy is real if virtual particles don't exist?"}
# m406873: {'question': 'Is it necessary to understand the mechanism behind the back？'}
# m379107: {'question': 'How is the novel atlas shrugged by ayn rand?'}
# m246097: {'question': "What's the best book on abstract algebra?"}
# m69310: {'question': 'How do you get rid of a sore throat?'}
# m131630: {'question': 'Why did global warming end up climate change?'}
# m342506: {'question': 'What is Yuvraj Singh like in real life?'}
# m463210: {'question': 'Why does it take 10 yards to get a first down in the NFL - and was this always the rule?'}
# m104095: {'question': 'What is the best torrent site for games?'}
# m94610: {'question': 'What is the cost of teeth scaling and teeth bleaching?'}
# m429810: {'question': 'What should I wear at my friends wedding?'}
# m9631: {'question': 'Why is the prime minister more powerful in India whereas the president is more powerful in the US?'}
# m198296: {'question': 'Why is my ex doing this?'}
# m174979: {'question': 'What can I do to improve India?'}
# m281948: {'question': 'How can you overcome your envy of people who are your age but are far more successful?'}
# m94094: {'question': 'What are the ways to earn money while studying?'}
# m13003: {'question': 'What is the best book for gate preparation?'}
# m2718: {'question': "What has been the best decision you've made in your life?"}
# m27685: {'question': 'Is material provided by ICAI sufficient for clearing CPT?'}
# m375609: {'question': 'What is a comparison of the Indian army commando and the US commando?'}
# m51468: {'question': 'What are the best books for GATE preparation?'}
# m375230: {'question': 'What is Gujarat famous for?'}
# m229366: {'question': 'Why am I obsessed with psychopaths?'}
# m147093: {'question': 'Is atheism another religion?'}
# m42806: {'question': 'How do I learn Spring Framework?'}
# m427239: {'question': 'Which computer programming language is harder: Python or Java?'}
# m63529: {'question': 'What do you usually do when you are alone at home?'}
# m204181: {'question': "I'm taking a drop for JEE Adv 2017. How do I study so that I can attempt 75-90 questions out of 120 questions in JEE Adv?"}
# m401253: {'question': "Now, that Mr. Najeeb Jung has resigned, can we believe Mr. Arvind Kejriwal's allegations about him to be correct?"}
# m27734: {'question': 'What is the best field for earning money after completing a B.Tech in mechanical engineering?'}
# m274941: {'question': "Why didn't the USA oppose Russia's permanent membership in the UNSC after disintegration of the USSR?"}
# m223750: {'question': 'What is the reputation of SSR Medical College Mauritius? Is it approved by the MCI?'}
# m38000: {'question': 'If there is only one God, then why do we praise different gods?'}
# m76195: {'question': "How does Google's new NOCAPTCHA reCAPTCHA work?"}
# m79612: {'question': 'What is the most probable cutoff for KVPY SA 2016?'}
# m322517: {'question': 'I am working for company X. My client is Y (US based). X had applied for the H1B (2015) visa and got the EAC** receipt on May, 2015. The USCIS status is “Case Was Received”. Now, I have an offer to join another company, Z. If I switch to company Z now, without getting my visa stamped from X, will my H1B VISA processing be cancelled?'}
# m432427: {'question': 'Is Deadpool as horrible for kids as he seems? What kind of potential damage are we talking about here?'}
# m344175: {'question': "Why don't you support the TPP?"}
# m128522: {'question': 'As an international student what factors should be considered while selecting universities in USA at undergraduate level of admission?'}
# m296359: {'question': 'What are the differences between Aikido and Judo?'}
# m20789: {'question': 'How do I increase my sexual stamina?'}
# m72988: {'question': 'Do elite military units and special forces teams in the military get higher salaries?'}
# m2854: {'question': 'Should I worry about what people think about me?'}
# m497032: {'question': 'How Kejariwal is expected to react to ban on 500/1000 currency notes?'}
# m103456: {'question': 'How we can post in Quora?'}
# m101302: {'question': 'What are the best and high PR social bookmarking site?'}
# m476089: {'question': 'How do I curl hair using oil?'}
# m242288: {'question': 'What are some effective ways to stop global warming?'}
# m174980: {'question': 'What can I do to improve India as a citizen of India?'}
# m241127: {'question': 'What is the story behind the alleged affair of SRK and Priyanka Chopra?'}
# m161679: {'question': 'How can I make money while am still in college?'}
# m114271: {'question': 'Does Switzerland keep records of people who go missing in national parks and wilderness areas? If not, why not?'}
# m191748: {'question': 'What are the strongest majors in terms of job prospects and what are the weakest majors at Morehouse College?'}
# m25032: {'question': 'Do new 2000 INR really have a NGC (Nano GPS Chip), or is it just a rumour?'}
# m443757: {'question': 'I have hurted my gf very badly. How should I convince her to forgive me?'}
# m505764: {'question': 'Are American parents in the future going to be helicopter parents?'}
# m33734: {'question': 'Can we stop global warming? Yeo/No? Why?'}
# m197944: {'question': 'How can I make money with the Internet and time?'}
# m56302: {'question': 'Is it true tat the new 2000 denomination currency has some Nano GPS chip? Or is it a rumour?'}
# m161927: {'question': 'What did the cavemen eat?'}
# m223751: {'question': 'What is the reputation of SSR Medical College, Mauritius. is it approved by MCI and is it good for indain students to go there?'}
# m413830: {'question': 'Can a 4 star general became president?'}
# m145009: {'question': 'How do I self rehab from masturbation and porn addiction?'}
# m86061: {'question': 'In practice, is the president or the prime minister the supreme power in Indian democracy?'}
# m451793: {'question': 'I am an B.E graduate in ECE working in an MNC . Is it good to take up MBA course in correspondence?'}
# m140418: {'question': 'How do you learn artificial intelligence?'}
# m439793: {'question': "How do I dress in the mid to late 80's gym gear that carried over into the year 1990 if I'm a guy?"}
# m8880: {'question': 'Is Donald Trump likely to win the 2016 election (late 2015 / early 2016)?'}
# m480129: {'question': 'How can you boost your cell phone signal?'}
# m131882: {'question': 'What is the toughest programming language to learn?'}
# m30800: {'question': 'Which is a good inpatient drug and alcohol rehab center in Union County IL?'}
# m19375: {'question': 'When will Apple release the new MacBook Pro in 2016?'}
# m426273: {'question': "Why hasn't Ivanka Trump condemned the bigotry in the Access Hollywood sex tape?"}
# m31340: {'question': 'How do I add photos to my questions on Quora?'}
# m362338: {'question': 'What are some cool YouTube usernames?'}
# m15795: {'question': 'Can God create a rock so big that even he cannot lift it?'}
# m104631: {'question': 'My father regularly lashes out in anger but then acts like nothing has happened a few hours later, is he suffering from a mental illness?'}
# m31365: {'question': 'HELP ASAP! Not able to login to Quora! What to do?'}
# m30512: {'question': 'How does in-flight Wi-Fi work?'}
# m220785: {'question': 'Why is the oldest oceanic lithosphere less than about 200 MA?'}
# m121962: {'question': 'How do I outsource software development for startups?'}
# m23350: {'question': 'Why do humans have 5 fingers?'}
# m317964: {'question': 'How can I use my time productively during slow day at work?'}
# m66698: {'question': 'What are the pros and cons in marrying a girl older than you?'}
# m212167: {'question': 'How can I improve sexual stamina?'}
# m353429: {'question': 'How exactly does the sun provide us with Vitamin D?'}
# m157458: {'question': 'How can I boost my cell phone signal at home?'}
# m303005: {'question': 'What are the differences between Judo and Aikido?'}
# m68719: {'question': 'Why should I learn JavaScript when I know Python?'}
# m42034: {'question': 'Is there a way to get taller, and increase your height?'}
# m331416: {'question': 'When did The College of New Jersey become Princeton? Why was the name changed?'}
# m375231: {'question': 'How is Gujarat Developed?'}
# m78770: {'question': 'Will Mike Pence becomes president after the impeachment of Trump?'}
# m283013: {'question': 'Is Delhi the way it should be?'}
# m42510: {'question': 'What is it like to be the President? In general.'}
# m429811: {'question': 'What should I wear to my friend’s wedding?'}
# m451131: {'question': 'How do you think outside the "think outside the box" box?'}
# m375608: {'question': 'What are requirements to become Indian para commando?'}
# m143137: {'question': 'How can I improve my aptitude for placement?'}
# m57941: {'question': 'Do you smoke weed ?'}
# m38270: {'question': "What are some mind-blowing mobile inventions that exist that most people don't know about?"}
